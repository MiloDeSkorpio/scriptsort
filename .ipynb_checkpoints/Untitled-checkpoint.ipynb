# %%
# imporatr las librerias necesarias para le funcionamiento
import os
import pandas as pd
# Directorio donde se encuentran los archivos CSV y la cual sera la base de trabajo del Script
ruta_guardado = "Validadores/Octubre"

# Definir el nombre del archivo que contendra la union de todos
validadores = "Validadores.csv"
# Definir los nombres de los archivos que se van a leer
archivos_a_leer = [
    "Acasa.csv",
    "Informe 1.2.csv",
    "Informe 1.3.csv",
    "Informe 1.4.csv",
    "Informe 1.5.csv",  
    "Microsafe.csv"
]

# Lista para almacenar los DataFrames de los archivos
dataframes = []

# Leer los archivos y almacenarlos en la lista de DataFrames
for archivo in archivos_a_leer:
    archivo_path = os.path.join(ruta_guardado, archivo)
    df = pd.read_csv(archivo_path)
    dataframes.append(df)

df_valid = pd.concat(dataframes,ignore_index=True)

ruta_validadores = os.path.join(ruta_guardado,validadores)
df_valid.to_csv(ruta_validadores,index=False)
# conteo de resultados por cada archivo y al final
# conteo de todos los resultados del DataFrame que contiene todos los archivos unidos
print(dataframes[0].shape)
print(dataframes[1].shape)
print(dataframes[2].shape)
print(dataframes[3].shape)
print(dataframes[4].shape)
print(dataframes[5].shape)
print(df_valid.shape)
df_filter = df_valid[df_valid['TIPO_TRANSACCION'] == "3"]
df_rechazo = df_valid[df_valid['TIPO_TRANSACCION'] == "51"] 
df_invalid = df_valid[df_valid['TIPO_TRANSACCION'].isnull() | (df_valid['TIPO_TRANSACCION'] == '')]
print("Transaccion = a 3",df_filter.shape)
print("Transaccion = a 51",df_rechazo.shape)
print("Transaccion = a null",df_invalid.shape)

linea1 = df_valid[df_valid['LINEA'] == "1"]

linea1.shape
df_valid['LINEA'].value_counts()
df_valid
# Out:
# (226, 38)
# (43133, 38)
# (396, 38)
# (28949, 38)
# (153, 38)
# (227834, 38)
# (300691, 38)
# Transaccion = a 3 (200178, 38)
# Transaccion = a 51 (21772, 38)
# Transaccion = a null (55, 38)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300691 entries, 0 to 300690
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ID_TRANSACCION_ORGANISMO       300691 non-null  int64
#  1   PROVIDER                       300691 non-null  int64
#  2   TIPO_TARJETA                   300691 non-null  int64
#  3   NUMERO_SERIE_HEX               300691 non-null  object
#  4   FECHA_HORA_TRANSACCION         300691 non-null  object
#  5   LINEA                          300691 non-null  object
#  6   ESTACION                       227834 non-null  object
#  7   AUTOBUS                        300295 non-null  object
#  8   RUTA                           300292 non-null  float64
#  9   EQUIPO                         72857 non-null   float64
#  10  TIPO_EQUIPO                    300691 non-null  object
#  11  LOCATION_ID                    300691 non-null  object
#  12  TIPO_TRANSACCION               300636 non-null  object
#  13  SALDO_ANTES_TRANSACCION        289978 non-null  float64
#  14  MONTO_TRANSACCION              296826 non-null  float64
#  15  SALDO_DESPUES_TRANSACCION      296829 non-null  float64
#  16  PERFIL1                        300691 non-null  object
#  17  PERFIL2                        300691 non-null  int64
#  18  PERFIL3                        300691 non-null  int64
#  19  SAM_SERIAL_HEX_ULTIMA_RECARGA  295698 non-null  object
#  20  SAM_SERIAL_HEX                 296824 non-null  object
#  21  CONTADOR_RECARGAS              0 non-null       float64
#  22  CONTADOR_VALIDACIONES          269842 non-null  float64
#  23  EVENT_LOG                      296739 non-null  object
#  24  LOAD_LOG                       227834 non-null  object
#  25  PURCHASE_LOG                   270121 non-null  object
#  26  MAC                            300621 non-null  object
#  27  COUNTER_VALUE                  72863 non-null   float64
#  28  COUNTER_AMOUNT                 72631 non-null   float64
#  29  SAM_COUNTER                    68959 non-null   object
#  30  ENVIRONMENT                    296739 non-null  object
#  31  ENVIRONMENT_ISSUER_ID          295158 non-null  object
#  32  CONTRACT                       296739 non-null  object
#  33  CONTRACT_TARIFF                296826 non-null  float64
#  34  CONTRACT_SALE_SAM              295742 non-null  object
#  35  CONTRACT_RESTRICT_TIME         68983 non-null   float64
#  36  CONTRACT_VALIDITY_START_DATE   295742 non-null  object
#  37  CONTRACT_VALIDITY_DURATION     295796 non-null  float64
# dtypes: float64(12), int64(5), object(21)
# memory usage: 87.2+ MB
